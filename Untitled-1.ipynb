# %%
import warnings 

warnings.filterwarnings("ignore") 

import tensorflow as tf 

from tensorflow.keras.preprocessing.image import ImageDataGenerator 

from tensorflow.keras.models import Sequential 

from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout 

from tensorflow.keras.optimizers import RMSprop 

import matplotlib.pyplot as plt

# %%
# Set paths to train and validation folders 

train_path = "C:/Users/Obito/OneDrive/Desktop/projects/Crop Disease Prediction using ML/Crop/Crop Disease/train"

valid_path = "C:/Users/Obito/OneDrive/Desktop/projects/Crop Disease Prediction using ML/Crop/Crop Disease/valid"

# %%
import os
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def display_random_images(directory, num_images=9, num_columns=3):
    # List subfolders in the directory
    subfolders = [subfolder for subfolder in os.listdir(directory) if os.path.isdir(os.path.join(directory, subfolder))]
    
    # Check if any subfolders exist
    if len(subfolders) == 0:
        print(f"No subfolders found in {directory}")
        return

    # Select a random subfolder
    random_subfolder = random.choice(subfolders)
    subfolder_path = os.path.join(directory, random_subfolder)
    
    # List all image files in the subfolder
    image_files = [filename for filename in os.listdir(subfolder_path) if filename.lower().endswith(('.png', '.jpg', '.jpeg'))]
    
    # Check if there are enough images to display
    if len(image_files) < num_images:
        print(f"Number of available images in {subfolder_path} is less than {num_images}")
        return
    
    # Randomly sample the required number of images
    random_files = random.sample(image_files, num_images)
    
    # Determine the number of rows for displaying images
    num_rows = (num_images + num_columns - 1) // num_columns
    plt.figure(figsize=(15, 10))
    
    # Display the images
    for i, filename in enumerate(random_files):
        img_path = os.path.join(subfolder_path, filename)
        try:
            img = mpimg.imread(img_path)
            plt.subplot(num_rows, num_columns, i + 1)
            plt.imshow(img)
            plt.axis('off')
            plt.title(filename)
        except Exception as e:
            print(f"Error loading image {img_path}: {e}")
    
    plt.tight_layout()
    plt.show()

# %%
# Call the function with the desired directory and number of images 

display_random_images(train_path, num_images=9, num_columns=3)

# %%
# Call the function with the desired directory and number of images 

display_random_images(valid_path, num_images=9, num_columns=3)

# %%
# Create a CNN model 

num_classes = len(train_generator.class_indices) 

model = Sequential([ 

 Conv2D(32, (3, 3), activation="relu", input_shape=(224, 224, 3)), 

 MaxPooling2D(2, 2), 

 Conv2D(64, (3, 3), activation="relu"), 

 MaxPooling2D(2, 2), 

 Flatten(), 

 Dense(128, activation="relu"), 

 Dropout(0.5), 

 Dense(num_classes, activation="softmax") 

]) 

 

from tensorflow.keras.optimizers import Adam

# %%
# Compile the model with Adam optimizer 

model.compile( 

  optimizer=Adam(learning_rate=0.0001), # You can adjust the learning rate as needed 

  loss="categorical_crossentropy", 

  metrics=["accuracy"] 

) 

 

from tensorflow.keras.callbacks import EarlyStopping

# %%
# Define the EarlyStopping callback 

early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Define the EarlyStopping callback
early_stopping = EarlyStopping(
    monitor='val_accuracy',  # Metric to monitor (can also be 'val_accuracy')
    patience=5,          # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True,  # Restore the best weights from when the monitored metric improved the most
    verbose=1            # Verbosity level (1 for output, 0 for no output)
)

# Train the model with EarlyStopping
history = model.fit(
    train_generator, 
    steps_per_epoch=len(train_generator), 
    epochs=50,  # Maximum number of epochs
    validation_data=valid_generator, 
    validation_steps=len(valid_generator), 
    callbacks=[early_stopping]  # Add the EarlyStopping callback
)
# Out:
# Epoch 1/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 272s 960ms/step - accuracy: 0.3812 - loss: 1.3665 - val_accuracy: 0.6886 - val_loss: 0.7484
# Epoch 2/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 119us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 208s 737ms/step - accuracy: 0.6782 - loss: 0.7785 - val_accuracy: 0.7870 - val_loss: 0.5845
# Epoch 4/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 78us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 206s 730ms/step - accuracy: 0.7598 - loss: 0.6021 - val_accuracy: 0.7919 - val_loss: 0.6032
# Epoch 6/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 81us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 205s 727ms/step - accuracy: 0.8238 - loss: 0.4697 - val_accuracy: 0.9051 - val_loss: 0.2785
# Epoch 8/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 59us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 201s 713ms/step - accuracy: 0.8420 - loss: 0.4132 - val_accuracy: 0.8452 - val_loss: 0.4675
# Epoch 10/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 70us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 200s 710ms/step - accuracy: 0.8646 - loss: 0.3630 - val_accuracy: 0.8563 - val_loss: 0.4189
# Epoch 12/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 77us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 197s 697ms/step - accuracy: 0.8814 - loss: 0.3314 - val_accuracy: 0.8980 - val_loss: 0.3138
# Epoch 14/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 55us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 198s 701ms/step - accuracy: 0.8834 - loss: 0.3029 - val_accuracy: 0.8864 - val_loss: 0.3087
# Epoch 16/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 71us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 198s 702ms/step - accuracy: 0.8919 - loss: 0.2799 - val_accuracy: 0.9117 - val_loss: 0.2812
# Epoch 18/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 77us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 197s 699ms/step - accuracy: 0.9023 - loss: 0.2557 - val_accuracy: 0.8381 - val_loss: 0.5381
# Epoch 20/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 193s 684ms/step - accuracy: 0.9142 - loss: 0.2389 - val_accuracy: 0.9170 - val_loss: 0.2516
# Epoch 22/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 58us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 197s 698ms/step - accuracy: 0.9190 - loss: 0.2197 - val_accuracy: 0.9485 - val_loss: 0.1493
# Epoch 24/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 62us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 193s 683ms/step - accuracy: 0.9138 - loss: 0.2357 - val_accuracy: 0.9401 - val_loss: 0.1892
# Epoch 26/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 83us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 198s 701ms/step - accuracy: 0.9255 - loss: 0.1994 - val_accuracy: 0.9357 - val_loss: 0.2041
# Epoch 28/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 56us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 196s 694ms/step - accuracy: 0.9292 - loss: 0.1932 - val_accuracy: 0.9197 - val_loss: 0.2099
# Epoch 30/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 55us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 204s 723ms/step - accuracy: 0.9314 - loss: 0.1825 - val_accuracy: 0.9086 - val_loss: 0.3029
# Epoch 32/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 55us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 191s 676ms/step - accuracy: 0.9315 - loss: 0.1853 - val_accuracy: 0.8913 - val_loss: 0.3726
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 23.

# %%
# Plot training and validation accuracy 

plt.plot(history.history["accuracy"], label="Training Accuracy") 

plt.plot(history.history["val_accuracy"], label="Validation Accuracy") 

plt.xlabel("Epochs") 

plt.ylabel("Accuracy") 

plt.title("Training and Validation Accuracy") 

plt.legend() 

plt.show()

# %%
# Plot training and validation loss 

plt.plot(history.history["loss"], label="Training Loss") 

plt.plot(history.history["val_loss"], label="Validation Loss") 

plt.xlabel("Epochs") 

plt.ylabel("Loss") 

plt.title("Training and Validation Loss") 

plt.legend() 

plt.show()

# %%
# Make predictions on test data 

test_loss, test_accuracy = model.evaluate(valid_generator, steps=len(valid_generator)) 

print(f"Test Loss: {test_loss:.4f}") 

print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.9446 - loss: 0.1588
# Test Loss: 0.1493
# Test Accuracy: 0.9485

# %%
# Save the trained model 

model.save("trained_model.h5") 

print("Trained model saved as 'trained_model.h5'") 

 

from sklearn.metrics import confusion_matrix 

import numpy as np 

import seaborn as sns
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Trained model saved as 'trained_model.h5'

# %%
# Load the saved model 

loaded_model = tf.keras.models.load_model("trained_model.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Initialize variables 

num_samples = len(valid_generator.filenames) 

batch_size = 32 

num_batches = int(np.ceil(num_samples / batch_size)) 

all_test_labels = [] 

all_predicted_labels = []

# %%
# Generate predictions in batches 

for _ in range(num_batches): 

 batch_images, batch_labels = next(valid_generator) 

 batch_predictions = loaded_model.predict(batch_images) 

 batch_predicted_labels = np.argmax(batch_predictions, axis=1) 
  

 all_test_labels.extend(np.argmax(batch_labels, axis=1)) 

 all_predicted_labels.extend(batch_predicted_labels)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step

# %%
# Generate confusion matrix 

cm = confusion_matrix(all_test_labels, all_predicted_labels)

# %%
# Plot the confusion matrix 

class_names = [str(i) for i in range(num_classes)] # Replace with actual class names if available 

plt.figure(figsize=(10, 8)) 

sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names) 

plt.xlabel('Predicted') 

plt.ylabel('Actual') 

plt.title('Confusion Matrix') 

plt.show()
